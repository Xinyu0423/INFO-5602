# %%
import altair as alt
import pandas as pd

data=pd.read_csv("tableau2 - Sheet1.csv")

# %%
data
# Out:
#                      Major  Year Homestate   GPA  Pets  Sleep (normal night)  \
# 0               Psychology     3        CA  3.90     0                   7.0
# 1      Information Science     5        WY  3.20     2                   7.0
# 2      Information Science     3        CO  3.80     1                   6.0
# 3      Information Science     3        GA  3.10     1                   5.0
# 4         Computer Science     2        CO  3.30     5                   4.0
# 5         Computer Science     4        TX  3.40     0                   9.0
# 6         Computer Science     3        AZ  3.80     1                   8.0
# 7      Geography & Ecology     4        CO  3.10     1                   9.0
# 8         Computer Science     4        AZ  3.60     4                   8.0
# 9      Information Science     4        CO  3.00     0                   6.0
# 10     Information Science     4        CO  3.00     0                   7.0
# ...

# %%
alt.Chart(data).mark_bar().encode(x="GPA",y="Pets")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_line().encode(x="GPA",y="Pets")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(x="Major",y="GPA")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_area().encode(x="Major",y="Sleep (normal night)")
# Out:
# alt.Chart(...)
